# %%
# Create folder 
from utils.create_folder import create_simulation_folder
results_dir = create_simulation_folder()
# Out:
# [INFO] Simulation folder created: results/2025-12-09_15-00-27

# %%
from milp.solve_gurobi_sequential import solve_gurobi_sequential, build_single_slice_model, update_remaining_capacities

# %%
from utils.topology import topology_bayern, draw_graph, topologie_finlande, topology_brazil
from utils.generate_slices import generate_random_slices
from milp.topology_to_instance import build_instance_from_topology
from milp.solver_gurobi import solve_gurobi      
from milp.adapter import MILPResultAdapterGurobi, MILPSequentialAdapter

import pandas as pd

# === Topology ===
G = topologie_finlande()

draw_graph(G)

# %%
# ============================
# Imports (clean and complete)
# ============================

import os
import time
import random
import numpy as np
import networkx as nx
import pandas as pd
from copy import deepcopy
from datetime import datetime
import re

# --- Safe filename function ---
def safe_filename(text):
    """Convert any string into a safe filename: no accents, spaces, or special chars."""
    text = text.lower()
    text = text.replace(" ", "_")
    text = re.sub(r"[^a-z0-9_\-]", "", text)
    return text

# --- Global reproducibility seed ---
GLOBAL_SEED = 42
random.seed(GLOBAL_SEED)
np.random.seed(GLOBAL_SEED)
os.environ["PYTHONHASHSEED"] = str(GLOBAL_SEED)

# --- MILP modules ---
from milp.create_instance import create_instance
from milp.solve_gurobi_sequential import (
    solve_gurobi_sequential,
    _get_slice_vl_pairs,
    NODE_ENERGY_WEIGHT,
    LINK_ENERGY_WEIGHT,
)

# --- Topologies ---
from utils.topology import topologie_finlande, topology_brazil

# --- Slice generation ---
from utils.generate_slices import generate_random_slices

# --- Graph generation ---
from utils.generate_graphs import plot_all_routes, plot_cpu_usage

# --- Heuristics ---
from heuristics.a_star import run_astar
from heuristics.run_abo_full_batch import run_abo_full_batch
from heuristics.run_fabo_full_batch import run_fabo_full_batch
from heuristics.best_fit import run_best_fit
from heuristics.first_fit import run_first_fit
from heuristics.a_star_energy_aware import energy_aware_astar

# --- Metrics ---
from utils.metrics import (
    count_accepted_slices,
    compute_energy_new,
    compute_total_bandwidth,
    compute_total_latency,
)

# ============================
# Helper: energy for sequential MILP
# ============================

def compute_seq_milp_energy(instance, seq_result):
    """Compute total node/link energy for the sequential MILP result.

    It uses the same proxy as in solve_gurobi_sequential:
      - Node energy: sum_n (cpu_used_n / CPU_cap[n])
      - Link energy: sum_(u,v) (bw_used_uv / BW_cap[(u,v)])
    """

    total_E_nodes = 0.0
    total_E_links = 0.0

    for s in seq_result["accepted_slices"]:
        res_s = seq_result["slice_results"][s]
        N = instance.N
        E = instance.E
        vl_pairs = _get_slice_vl_pairs(instance, s)

        # ---- Node energy for this slice ----
        node_terms = []
        for n in N:
            cpu_used_n = 0.0
            for i in instance.V_of_s[s]:
                x_val = res_s.values.get(("x", s, i, n), 0.0)
                cpu_used_n += instance.CPU_i[i] * x_val
            cap_n = instance.CPU_cap[n]
            if cap_n > 0:
                node_terms.append(cpu_used_n / cap_n)
        E_nodes_s = NODE_ENERGY_WEIGHT * sum(node_terms)

        # ---- Link energy for this slice ----
        link_terms = []
        for (u, v) in E:
            bw_used_uv = 0.0
            for (i, j) in vl_pairs:
                f_val = res_s.values.get(("f", s, i, j, u, v), 0.0)
                bw_used_uv += f_val
            cap_uv = instance.BW_cap[(u, v)]
            if cap_uv > 0:
                link_terms.append(bw_used_uv / cap_uv)
        E_links_s = LINK_ENERGY_WEIGHT * sum(link_terms)

        total_E_nodes += E_nodes_s
        total_E_links += E_links_s

    return total_E_nodes, total_E_links, (total_E_nodes + total_E_links)


# ============================
# Directories for results
# ============================

timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
results_dir = os.path.join("./results", safe_filename(timestamp))
os.makedirs(results_dir, exist_ok=True)

routes_dir = os.path.join(results_dir, "routes")
cpu_dir = os.path.join(results_dir, "cpu_usage")
os.makedirs(routes_dir, exist_ok=True)
os.makedirs(cpu_dir, exist_ok=True)

print(f"[INFO] Results will be saved under: {results_dir}")

# --- Global MILP / experiment parameters ---
MILP_TIME_LIMIT = 300
ENTRY = 6
MAX_MILP_SLICES = 128
MAX_MILP_VNFS_TOTAL = 512

# --- Topology ---
G = topologie_finlande()
ENTRY = 6
pos = nx.spring_layout(G, seed=GLOBAL_SEED)

# --- VNF profiles ---
vnf_profiles = [
    {"cpu": 2,  "throughput": 30, "latency": 80},   # light
    {"cpu": 3,  "throughput": 40, "latency": 110},  # slightly heavier
    {"cpu": 4,  "throughput": 50, "latency": 140},  # medium
    {"cpu": 6,  "throughput": 65, "latency": 180},  # medium-heavy
    {"cpu": 8,  "throughput": 80, "latency": 220},  # heavy
    {"cpu": 10, "throughput": 95, "latency": 260},  # very heavy
]

# --- Base capacities ---
node_capacity_base = {n: G.nodes[n]["cpu"] for n in G.nodes}
link_capacity_base = {(u, v): G[u][v]["bandwidth"] for u, v in G.edges}
link_capacity_base.update({(v, u): G[u][v]["bandwidth"] for u, v in G.edges})
link_latency = {(u, v): G[u][v]["latency"] for u, v in G.edges}
link_latency.update({(v, u): G[u][v]["latency"] for u, v in G.edges})

# --- Parameter grid ---
param_grid = {
    "num_slices": [6, 8, 12, 16, 32],
    "num_vnfs_per_slice": [2, 3, 4, 5, 6],
    "seed": list(range(1)),
}

max_slices = max(param_grid["num_slices"])

# IMPORTANT: reset records before the main loop
records = []

try:
    # ------------------------------------------------------------------
    # Main experiment loop with a fixed pool of slices per (vnf, seed)
    # ------------------------------------------------------------------
    for num_vnfs in param_grid["num_vnfs_per_slice"]:
        for seed in param_grid["seed"]:
            # Fix per-(num_vnfs, seed) randomness
            random.seed(seed)
            np.random.seed(seed)

            print(f"\n[INFO] === Pre-generating slice pool: max_slices={max_slices}, "
                  f"VNFs={num_vnfs}, seed={seed} ===")

            slice_pool = generate_random_slices(
                G,
                vnf_profiles,
                num_slices=max_slices,
                num_vnfs_per_slice=num_vnfs,
                entry=ENTRY,
            )

            if len(slice_pool) < max_slices:
                print(f"[WARN] slice_pool has only {len(slice_pool)} entries (expected {max_slices}).")

            # Sweep number of slices for this (num_vnfs, seed)
            for num_slices in param_grid["num_slices"]:
                total_vnfs = num_slices * num_vnfs

                print(f"\n[INFO] === Running Load Test: {num_slices} slices × "
                      f"{num_vnfs} VNFs (total={total_vnfs}), seed={seed} ===")

                # Use the first num_slices from the fixed pool
                slices = deepcopy(slice_pool[:num_slices])
                method_results = {}
                method_times = {}

                # --- Heuristics ---
                for name, func, args in [
                    ("A*", run_astar, (G, slices, node_capacity_base, link_capacity_base)),
                    ("ABO", run_abo_full_batch, (G, slices, node_capacity_base, link_latency, link_capacity_base)),
                    ("FABO", run_fabo_full_batch, (G, slices, node_capacity_base, link_latency, link_capacity_base)),
                    ("Best Fit", run_best_fit, (G, slices, node_capacity_base, link_capacity_base, link_latency)),
                    ("First Fit", run_first_fit, (G, slices, node_capacity_base, link_capacity_base, link_latency)),
                    ("Energy-Aware A*", energy_aware_astar,
                     (G, slices, node_capacity_base, link_capacity_base, 0.6, 0.4)),
                ]:
                    start = time.time()
                    try:
                        df_res, res_list = func(*args)
                        method_results[name] = res_list
                    except Exception as e:
                        print(f"[ERROR] {name} failed: {e}")
                        method_results[name] = []
                    method_times[name] = time.time() - start

                # --- Sequential MILP (optional, limited by size) ---
                if num_slices <= MAX_MILP_SLICES and total_vnfs <= MAX_MILP_VNFS_TOTAL:
                    try:
                        print(f"\n[INFO][MILP-SEQ] Running Sequential MILP…")
                        start = time.time()

                        # Build instance compatible with solve_gurobi_sequential
                        instance = create_instance(G, slices)
                        instance.entry_node = ENTRY  # kept for compatibility if used elsewhere

                        seq_res = solve_gurobi_sequential(
                            instance,
                            msg=False,
                            time_limit=MILP_TIME_LIMIT,
                        )
                        milp_seq_runtime = time.time() - start

                        # Wrap in adapter so plotting functions can see VNFs and routes
                        adapter_seq = MILPSequentialAdapter(seq_res, instance)
                        result_list_seq = [adapter_seq]

                      
                        method_results["MILP_Sequential"] = result_list_seq
                        method_times["MILP_Sequential"] = milp_seq_runtime

                       
                        accepted_seq = len(seq_res["accepted_slices"])
                        E_nodes_seq, E_links_seq, E_total_seq = compute_seq_milp_energy(
                            instance, seq_res
                        )
                        total_bw_seq = None
                        total_lat_seq = None

                        records.append({
                            "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
                            "num_slices": num_slices,
                            "num_vnfs_per_slice": num_vnfs,
                            "total_vnfs": total_vnfs,
                            "seed": seed,
                            "method": "MILP_Sequential",
                            "accepted": accepted_seq,
                            "total_energy": E_total_seq,
                            "total_bandwidth": total_bw_seq,
                            "total_latency": total_lat_seq,
                            "runtime_sec": milp_seq_runtime,
                        })

                    except Exception as e:
                        print(f"[ERROR][MILP-SEQ] Failed: {e}")


                # ----------------------------------------
                # Per-scenario visualizations
                # ----------------------------------------
                for method_name, result_list in method_results.items():
                    if not result_list:
                        continue

                    safe_img_name = safe_filename(
                        f"{method_name}_slices{num_slices}_vnfs{num_vnfs}_seed{seed}"
                    )

                    plot_all_routes(
                        G,
                        result_list,
                        title="All routed paths",
                        results_dir=routes_dir,
                        num_slices=num_slices,
                        num_vnfs_per_slice=num_vnfs,
                        seed=seed,
                        method_name=safe_img_name,
                        # pos=pos,  # uncomment if function supports fixed layout
                    )

                # CPU usage plot (all methods for this scenario)
                plot_cpu_usage(
                    G,
                    slices,
                    method_results,
                    results_dir=cpu_dir,
                    num_slices=num_slices,
                    num_vnfs_per_slice=num_vnfs,
                    seed=seed,
                )

                # --- Metrics for heuristics ---
                for method_name, result_list in method_results.items():
                    if not result_list:
                        continue
                    try:
                        accepted = count_accepted_slices(result_list, slices)
                        total_energy = compute_energy_new(
                            result_list, slices, node_capacity_base, link_capacity_base
                        )
                        total_bw = sum(b for b in compute_total_bandwidth(result_list, slices) if b)
                        total_lat = sum(l for l in compute_total_latency(result_list, link_latency) if l)

                        records.append({
                            "timestamp": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
                            "num_slices": num_slices,
                            "num_vnfs_per_slice": num_vnfs,
                            "total_vnfs": total_vnfs,
                            "seed": seed,
                            "method": method_name,
                            "accepted": accepted,
                            "total_energy": total_energy,
                            "total_bandwidth": total_bw,
                            "total_latency": total_lat,
                            "runtime_sec": method_times[method_name],
                        })
                    except Exception as e:
                        print(f"[ERROR] Metrics failed for {method_name}, "
                              f"slices={num_slices}, vnfs={num_vnfs}, seed={seed}: {e}")

finally:
    # --- Save results even if something failed ---
    df_results = pd.DataFrame(records)

    if not df_results.empty:
        dup = df_results.groupby(["method", "num_slices", "num_vnfs_per_slice", "seed"]).size()
        print("[CHECK] Max repetitions:", dup.max())
    else:
        print("[WARN] df_results is empty, nothing to group.")

    output_path = os.path.join(results_dir, "scalability_results.csv")
    df_results.to_csv(output_path, index=False)
    print(f"\n[INFO] Results saved to {output_path}")
    print(f"[INFO] records generated: {len(records)}")
    print(f"[INFO] CSV exists? {os.path.exists(output_path)}")
# Out:
# [INFO] Results will be saved under: ./results/2025-12-09_15-00-33
#
# [INFO] === Pre-generating slice pool: max_slices=32, VNFs=2, seed=0 ===
#
# [INFO] === Running Load Test: 6 slices × 2 VNFs (total=12), seed=0 ===
#
# [INFO][A*] === Solving slice 1 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 1 accepted.
#
#
# [INFO][A*] === Solving slice 2 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 2 accepted.
#
#
# [INFO][A*] === Solving slice 3 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 3 accepted.
#
#
# [INFO][A*] === Solving slice 4 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 4 accepted.
#
#
# [INFO][A*] === Solving slice 5 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 5 accepted.
#
#
# [INFO][A*] === Solving slice 6 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 6 accepted.
#
#
# [INFO][ABO] === Solving slice 1 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 1 accepted. min_node_cpu=14, links_low_bw=0
#
# [INFO][ABO] === Solving slice 2 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 2 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][ABO] === Solving slice 3 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 3 accepted. min_node_cpu=10, links_low_bw=0
#
# [INFO][ABO] === Solving slice 4 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 4 accepted. min_node_cpu=8, links_low_bw=0
#
# [INFO][ABO] === Solving slice 5 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 5 accepted. min_node_cpu=6, links_low_bw=0
#
# [INFO][ABO] === Solving slice 6 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 6 accepted. min_node_cpu=4, links_low_bw=0
#
# [INFO][FABO] === Solving slice 1 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 1 accepted. min_node_cpu=14, links_low_bw=0
#
# [INFO][FABO] === Solving slice 2 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 2 accepted. min_node_cpu=13, links_low_bw=0
#
# [INFO][FABO] === Solving slice 3 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 3 accepted. min_node_cpu=13, links_low_bw=0
#
# [INFO][FABO] === Solving slice 4 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 4 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][FABO] === Solving slice 5 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 5 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][FABO] === Solving slice 6 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 6 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][BF] === Solving slice 1 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf0_0 on node 6 (use=2, remaining=62).
# [INFO][BF] Placed vnf0_1 on node 2 (use=3, remaining=13).
# [SUMMARY][BF] Slice 1 accepted. Remaining min_node_cpu=13, links_low_bw=0
#
# [INFO][BF] === Solving slice 2 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf1_0 on node 6 (use=2, remaining=60).
# [INFO][BF] Placed vnf1_1 on node 2 (use=3, remaining=10).
# [SUMMARY][BF] Slice 2 accepted. Remaining min_node_cpu=10, links_low_bw=0
#
# [INFO][BF] === Solving slice 3 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf2_0 on node 6 (use=2, remaining=58).
# [INFO][BF] Placed vnf2_1 on node 2 (use=3, remaining=7).
# [SUMMARY][BF] Slice 3 accepted. Remaining min_node_cpu=7, links_low_bw=0
#
# [INFO][BF] === Solving slice 4 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf3_0 on node 6 (use=2, remaining=56).
# [INFO][BF] Placed vnf3_1 on node 2 (use=3, remaining=4).
# [SUMMARY][BF] Slice 4 accepted. Remaining min_node_cpu=4, links_low_bw=0
#
# [INFO][BF] === Solving slice 5 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf4_0 on node 6 (use=2, remaining=54).
# [INFO][BF] Placed vnf4_1 on node 2 (use=3, remaining=1).
# [SUMMARY][BF] Slice 5 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 6 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf5_0 on node 6 (use=2, remaining=52).
# [INFO][BF] Placed vnf5_1 on node 5 (use=3, remaining=13).
# [SUMMARY][BF] Slice 6 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 1 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf0_0 on node 1 (use=2, remaining=62).
# [INFO][FF] Placed vnf0_1 on node 2 (use=3, remaining=13).
# [SUMMARY][FF] Slice 1 accepted. Remaining min_node_cpu=13, links_low_bw=0
#
# [INFO][FF] === Solving slice 2 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf1_0 on node 1 (use=2, remaining=60).
# [INFO][FF] Placed vnf1_1 on node 2 (use=3, remaining=10).
# [SUMMARY][FF] Slice 2 accepted. Remaining min_node_cpu=10, links_low_bw=0
#
# [INFO][FF] === Solving slice 3 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf2_0 on node 1 (use=2, remaining=58).
# [INFO][FF] Placed vnf2_1 on node 2 (use=3, remaining=7).
# [SUMMARY][FF] Slice 3 accepted. Remaining min_node_cpu=7, links_low_bw=0
#
# [INFO][FF] === Solving slice 4 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf3_0 on node 1 (use=2, remaining=56).
# [INFO][FF] Placed vnf3_1 on node 2 (use=3, remaining=4).
# [SUMMARY][FF] Slice 4 accepted. Remaining min_node_cpu=4, links_low_bw=0
#
# [INFO][FF] === Solving slice 5 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf4_0 on node 1 (use=2, remaining=54).
# [INFO][FF] Placed vnf4_1 on node 2 (use=3, remaining=1).
# [SUMMARY][FF] Slice 5 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 6 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf5_0 on node 1 (use=2, remaining=52).
# [INFO][FF] Placed vnf5_1 on node 3 (use=3, remaining=13).
# [SUMMARY][FF] Slice 6 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][A*-Energy/Infra] === Solving slice 1 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 1 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 2 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 2 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 3 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 3 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 4 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 4 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 5 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 5 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 6 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 6 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][MILP-SEQ] Running Sequential MILP…
# Restricted license - for non-production use only - expires 2027-11-29
# /home/cecilia/5g-slicing-energy-effiiciency/simulator/utils/generate_graphs.py:200: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_a_slices6_vnfs2_seed0_s6_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_abo_slices6_vnfs2_seed0_s6_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_fabo_slices6_vnfs2_seed0_s6_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_best_fit_slices6_vnfs2_seed0_s6_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_first_fit_slices6_vnfs2_seed0_s6_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_energy-aware_a_slices6_vnfs2_seed0_s6_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_milp_sequential_slices6_vnfs2_seed0_s6_v2_seed0.png
# [INFO] Saved CPU utilization chart to ./results/2025-12-09_15-00-33/cpu_usage/cpu_utilization_s6_v2_seed0.png
#
# [INFO] === Running Load Test: 8 slices × 2 VNFs (total=16), seed=0 ===
#
# [INFO][A*] === Solving slice 1 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 1 accepted.
#
#
# [INFO][A*] === Solving slice 2 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 2 accepted.
#
#
# [INFO][A*] === Solving slice 3 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 3 accepted.
#
#
# [INFO][A*] === Solving slice 4 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 4 accepted.
#
#
# [INFO][A*] === Solving slice 5 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 5 accepted.
#
#
# [INFO][A*] === Solving slice 6 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 6 accepted.
#
#
# [INFO][A*] === Solving slice 7 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 7 accepted.
#
#
# [INFO][A*] === Solving slice 8 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 8 accepted.
#
#
# [INFO][ABO] === Solving slice 1 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 1 accepted. min_node_cpu=14, links_low_bw=0
#
# [INFO][ABO] === Solving slice 2 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 2 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][ABO] === Solving slice 3 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 3 accepted. min_node_cpu=10, links_low_bw=0
#
# [INFO][ABO] === Solving slice 4 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 4 accepted. min_node_cpu=8, links_low_bw=0
#
# [INFO][ABO] === Solving slice 5 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 5 accepted. min_node_cpu=6, links_low_bw=0
#
# [INFO][ABO] === Solving slice 6 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 6 accepted. min_node_cpu=4, links_low_bw=0
#
# [INFO][ABO] === Solving slice 7 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 7 accepted. min_node_cpu=2, links_low_bw=0
#
# [INFO][ABO] === Solving slice 8 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 8 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][FABO] === Solving slice 1 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 1 accepted. min_node_cpu=14, links_low_bw=0
#
# [INFO][FABO] === Solving slice 2 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 2 accepted. min_node_cpu=13, links_low_bw=0
#
# [INFO][FABO] === Solving slice 3 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 3 accepted. min_node_cpu=13, links_low_bw=0
#
# [INFO][FABO] === Solving slice 4 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 4 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][FABO] === Solving slice 5 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 5 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][FABO] === Solving slice 6 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 6 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][FABO] === Solving slice 7 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 7 accepted. min_node_cpu=10, links_low_bw=0
#
# [INFO][FABO] === Solving slice 8 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 8 accepted. min_node_cpu=10, links_low_bw=0
#
# [INFO][BF] === Solving slice 1 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf0_0 on node 6 (use=2, remaining=62).
# [INFO][BF] Placed vnf0_1 on node 2 (use=3, remaining=13).
# [SUMMARY][BF] Slice 1 accepted. Remaining min_node_cpu=13, links_low_bw=0
#
# [INFO][BF] === Solving slice 2 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf1_0 on node 6 (use=2, remaining=60).
# [INFO][BF] Placed vnf1_1 on node 2 (use=3, remaining=10).
# [SUMMARY][BF] Slice 2 accepted. Remaining min_node_cpu=10, links_low_bw=0
#
# [INFO][BF] === Solving slice 3 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf2_0 on node 6 (use=2, remaining=58).
# [INFO][BF] Placed vnf2_1 on node 2 (use=3, remaining=7).
# [SUMMARY][BF] Slice 3 accepted. Remaining min_node_cpu=7, links_low_bw=0
#
# [INFO][BF] === Solving slice 4 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf3_0 on node 6 (use=2, remaining=56).
# [INFO][BF] Placed vnf3_1 on node 2 (use=3, remaining=4).
# [SUMMARY][BF] Slice 4 accepted. Remaining min_node_cpu=4, links_low_bw=0
#
# [INFO][BF] === Solving slice 5 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf4_0 on node 6 (use=2, remaining=54).
# [INFO][BF] Placed vnf4_1 on node 2 (use=3, remaining=1).
# [SUMMARY][BF] Slice 5 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 6 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf5_0 on node 6 (use=2, remaining=52).
# [INFO][BF] Placed vnf5_1 on node 5 (use=3, remaining=13).
# [SUMMARY][BF] Slice 6 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 7 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf6_0 on node 6 (use=2, remaining=50).
# [INFO][BF] Placed vnf6_1 on node 5 (use=3, remaining=10).
# [SUMMARY][BF] Slice 7 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 8 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf7_0 on node 6 (use=2, remaining=48).
# [INFO][BF] Placed vnf7_1 on node 5 (use=3, remaining=7).
# [SUMMARY][BF] Slice 8 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 1 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf0_0 on node 1 (use=2, remaining=62).
# [INFO][FF] Placed vnf0_1 on node 2 (use=3, remaining=13).
# [SUMMARY][FF] Slice 1 accepted. Remaining min_node_cpu=13, links_low_bw=0
#
# [INFO][FF] === Solving slice 2 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf1_0 on node 1 (use=2, remaining=60).
# [INFO][FF] Placed vnf1_1 on node 2 (use=3, remaining=10).
# [SUMMARY][FF] Slice 2 accepted. Remaining min_node_cpu=10, links_low_bw=0
#
# [INFO][FF] === Solving slice 3 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf2_0 on node 1 (use=2, remaining=58).
# [INFO][FF] Placed vnf2_1 on node 2 (use=3, remaining=7).
# [SUMMARY][FF] Slice 3 accepted. Remaining min_node_cpu=7, links_low_bw=0
#
# [INFO][FF] === Solving slice 4 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf3_0 on node 1 (use=2, remaining=56).
# [INFO][FF] Placed vnf3_1 on node 2 (use=3, remaining=4).
# [SUMMARY][FF] Slice 4 accepted. Remaining min_node_cpu=4, links_low_bw=0
#
# [INFO][FF] === Solving slice 5 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf4_0 on node 1 (use=2, remaining=54).
# [INFO][FF] Placed vnf4_1 on node 2 (use=3, remaining=1).
# [SUMMARY][FF] Slice 5 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 6 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf5_0 on node 1 (use=2, remaining=52).
# [INFO][FF] Placed vnf5_1 on node 3 (use=3, remaining=13).
# [SUMMARY][FF] Slice 6 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 7 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf6_0 on node 1 (use=2, remaining=50).
# [INFO][FF] Placed vnf6_1 on node 3 (use=3, remaining=10).
# [SUMMARY][FF] Slice 7 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 8 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf7_0 on node 1 (use=2, remaining=48).
# [INFO][FF] Placed vnf7_1 on node 3 (use=3, remaining=7).
# [SUMMARY][FF] Slice 8 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][A*-Energy/Infra] === Solving slice 1 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 1 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 2 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 2 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 3 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 3 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 4 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 4 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 5 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 5 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 6 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 6 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 7 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 7 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 8 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 8 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][MILP-SEQ] Running Sequential MILP…
# /home/cecilia/5g-slicing-energy-effiiciency/simulator/utils/generate_graphs.py:200: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_a_slices8_vnfs2_seed0_s8_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_abo_slices8_vnfs2_seed0_s8_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_fabo_slices8_vnfs2_seed0_s8_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_best_fit_slices8_vnfs2_seed0_s8_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_first_fit_slices8_vnfs2_seed0_s8_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_energy-aware_a_slices8_vnfs2_seed0_s8_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_milp_sequential_slices8_vnfs2_seed0_s8_v2_seed0.png
# [INFO] Saved CPU utilization chart to ./results/2025-12-09_15-00-33/cpu_usage/cpu_utilization_s8_v2_seed0.png
#
# [INFO] === Running Load Test: 12 slices × 2 VNFs (total=24), seed=0 ===
#
# [INFO][A*] === Solving slice 1 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 1 accepted.
#
#
# [INFO][A*] === Solving slice 2 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 2 accepted.
#
#
# [INFO][A*] === Solving slice 3 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 3 accepted.
#
#
# [INFO][A*] === Solving slice 4 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 4 accepted.
#
#
# [INFO][A*] === Solving slice 5 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 5 accepted.
#
#
# [INFO][A*] === Solving slice 6 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 6 accepted.
#
#
# [INFO][A*] === Solving slice 7 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 7 accepted.
#
#
# [INFO][A*] === Solving slice 8 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 8 accepted.
#
#
# [INFO][A*] === Solving slice 9 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 9 accepted.
#
#
# [INFO][A*] === Solving slice 10 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 10 accepted.
#
#
# [INFO][A*] === Solving slice 11 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 11 accepted.
#
#
# [INFO][A*] === Solving slice 12 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 12 accepted.
#
#
# [INFO][ABO] === Solving slice 1 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 1 accepted. min_node_cpu=14, links_low_bw=0
#
# [INFO][ABO] === Solving slice 2 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 2 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][ABO] === Solving slice 3 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 3 accepted. min_node_cpu=10, links_low_bw=0
#
# [INFO][ABO] === Solving slice 4 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 4 accepted. min_node_cpu=8, links_low_bw=0
#
# [INFO][ABO] === Solving slice 5 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 5 accepted. min_node_cpu=6, links_low_bw=0
#
# [INFO][ABO] === Solving slice 6 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 6 accepted. min_node_cpu=4, links_low_bw=0
#
# [INFO][ABO] === Solving slice 7 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 7 accepted. min_node_cpu=2, links_low_bw=0
#
# [INFO][ABO] === Solving slice 8 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 8 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 9 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 9 states.
# [SUMMARY][ABO] Slice 9 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 10 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 9 states.
# [SUMMARY][ABO] Slice 10 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 11 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 9 states.
# [SUMMARY][ABO] Slice 11 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 12 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 9 states.
# [SUMMARY][ABO] Slice 12 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][FABO] === Solving slice 1 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 1 accepted. min_node_cpu=14, links_low_bw=0
#
# [INFO][FABO] === Solving slice 2 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 2 accepted. min_node_cpu=13, links_low_bw=0
#
# [INFO][FABO] === Solving slice 3 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 3 accepted. min_node_cpu=13, links_low_bw=0
#
# [INFO][FABO] === Solving slice 4 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 4 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][FABO] === Solving slice 5 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 5 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][FABO] === Solving slice 6 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 6 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][FABO] === Solving slice 7 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 7 accepted. min_node_cpu=10, links_low_bw=0
#
# [INFO][FABO] === Solving slice 8 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 8 accepted. min_node_cpu=10, links_low_bw=0
#
# [INFO][FABO] === Solving slice 9 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 9 accepted. min_node_cpu=10, links_low_bw=0
#
# [INFO][FABO] === Solving slice 10 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 10 accepted. min_node_cpu=8, links_low_bw=0
#
# [INFO][FABO] === Solving slice 11 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 11 accepted. min_node_cpu=8, links_low_bw=0
#
# [INFO][FABO] === Solving slice 12 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 12 accepted. min_node_cpu=8, links_low_bw=0
#
# [INFO][BF] === Solving slice 1 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf0_0 on node 6 (use=2, remaining=62).
# [INFO][BF] Placed vnf0_1 on node 2 (use=3, remaining=13).
# [SUMMARY][BF] Slice 1 accepted. Remaining min_node_cpu=13, links_low_bw=0
#
# [INFO][BF] === Solving slice 2 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf1_0 on node 6 (use=2, remaining=60).
# [INFO][BF] Placed vnf1_1 on node 2 (use=3, remaining=10).
# [SUMMARY][BF] Slice 2 accepted. Remaining min_node_cpu=10, links_low_bw=0
#
# [INFO][BF] === Solving slice 3 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf2_0 on node 6 (use=2, remaining=58).
# [INFO][BF] Placed vnf2_1 on node 2 (use=3, remaining=7).
# [SUMMARY][BF] Slice 3 accepted. Remaining min_node_cpu=7, links_low_bw=0
#
# [INFO][BF] === Solving slice 4 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf3_0 on node 6 (use=2, remaining=56).
# [INFO][BF] Placed vnf3_1 on node 2 (use=3, remaining=4).
# [SUMMARY][BF] Slice 4 accepted. Remaining min_node_cpu=4, links_low_bw=0
#
# [INFO][BF] === Solving slice 5 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf4_0 on node 6 (use=2, remaining=54).
# [INFO][BF] Placed vnf4_1 on node 2 (use=3, remaining=1).
# [SUMMARY][BF] Slice 5 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 6 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf5_0 on node 6 (use=2, remaining=52).
# [INFO][BF] Placed vnf5_1 on node 5 (use=3, remaining=13).
# [SUMMARY][BF] Slice 6 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 7 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf6_0 on node 6 (use=2, remaining=50).
# [INFO][BF] Placed vnf6_1 on node 5 (use=3, remaining=10).
# [SUMMARY][BF] Slice 7 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 8 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf7_0 on node 6 (use=2, remaining=48).
# [INFO][BF] Placed vnf7_1 on node 5 (use=3, remaining=7).
# [SUMMARY][BF] Slice 8 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 9 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf8_0 on node 6 (use=2, remaining=46).
# [INFO][BF] Placed vnf8_1 on node 5 (use=3, remaining=4).
# [SUMMARY][BF] Slice 9 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 10 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf9_0 on node 6 (use=2, remaining=44).
# [INFO][BF] Placed vnf9_1 on node 5 (use=3, remaining=1).
# [SUMMARY][BF] Slice 10 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 11 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf10_0 on node 6 (use=2, remaining=42).
# [INFO][BF] Placed vnf10_1 on node 7 (use=3, remaining=13).
# [SUMMARY][BF] Slice 11 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 12 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf11_0 on node 6 (use=2, remaining=40).
# [INFO][BF] Placed vnf11_1 on node 7 (use=3, remaining=10).
# [SUMMARY][BF] Slice 12 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 1 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf0_0 on node 1 (use=2, remaining=62).
# [INFO][FF] Placed vnf0_1 on node 2 (use=3, remaining=13).
# [SUMMARY][FF] Slice 1 accepted. Remaining min_node_cpu=13, links_low_bw=0
#
# [INFO][FF] === Solving slice 2 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf1_0 on node 1 (use=2, remaining=60).
# [INFO][FF] Placed vnf1_1 on node 2 (use=3, remaining=10).
# [SUMMARY][FF] Slice 2 accepted. Remaining min_node_cpu=10, links_low_bw=0
#
# [INFO][FF] === Solving slice 3 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf2_0 on node 1 (use=2, remaining=58).
# [INFO][FF] Placed vnf2_1 on node 2 (use=3, remaining=7).
# [SUMMARY][FF] Slice 3 accepted. Remaining min_node_cpu=7, links_low_bw=0
#
# [INFO][FF] === Solving slice 4 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf3_0 on node 1 (use=2, remaining=56).
# [INFO][FF] Placed vnf3_1 on node 2 (use=3, remaining=4).
# [SUMMARY][FF] Slice 4 accepted. Remaining min_node_cpu=4, links_low_bw=0
#
# [INFO][FF] === Solving slice 5 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf4_0 on node 1 (use=2, remaining=54).
# [INFO][FF] Placed vnf4_1 on node 2 (use=3, remaining=1).
# [SUMMARY][FF] Slice 5 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 6 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf5_0 on node 1 (use=2, remaining=52).
# [INFO][FF] Placed vnf5_1 on node 3 (use=3, remaining=13).
# [SUMMARY][FF] Slice 6 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 7 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf6_0 on node 1 (use=2, remaining=50).
# [INFO][FF] Placed vnf6_1 on node 3 (use=3, remaining=10).
# [SUMMARY][FF] Slice 7 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 8 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf7_0 on node 1 (use=2, remaining=48).
# [INFO][FF] Placed vnf7_1 on node 3 (use=3, remaining=7).
# [SUMMARY][FF] Slice 8 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 9 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf8_0 on node 1 (use=2, remaining=46).
# [INFO][FF] Placed vnf8_1 on node 3 (use=3, remaining=4).
# [SUMMARY][FF] Slice 9 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 10 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf9_0 on node 1 (use=2, remaining=44).
# [INFO][FF] Placed vnf9_1 on node 3 (use=3, remaining=1).
# [SUMMARY][FF] Slice 10 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 11 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf10_0 on node 1 (use=2, remaining=42).
# [INFO][FF] Placed vnf10_1 on node 4 (use=3, remaining=13).
# [SUMMARY][FF] Slice 11 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 12 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf11_0 on node 1 (use=2, remaining=40).
# [INFO][FF] Placed vnf11_1 on node 4 (use=3, remaining=10).
# [SUMMARY][FF] Slice 12 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][A*-Energy/Infra] === Solving slice 1 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 1 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 2 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 2 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 3 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 3 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 4 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 4 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 5 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 5 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 6 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 6 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 7 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 7 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 8 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 8 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 9 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 9 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 10 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 10 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 11 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 11 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][A*-Energy/Infra] === Solving slice 12 (VNFs=2, VLs=1) ===
# [INFO][A*-Energy/Infra] Solution after 6 expansions. (nodes=2, links=1, energy=0.1800)
# [SUMMARY][A*-Energy/Infra] Slice 12 accepted. (nodes=2, links=1, energy=0.1800)
#
#
# [INFO][MILP-SEQ] Running Sequential MILP…
# /home/cecilia/5g-slicing-energy-effiiciency/simulator/utils/generate_graphs.py:200: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_a_slices12_vnfs2_seed0_s12_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_abo_slices12_vnfs2_seed0_s12_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_fabo_slices12_vnfs2_seed0_s12_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_best_fit_slices12_vnfs2_seed0_s12_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_first_fit_slices12_vnfs2_seed0_s12_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_energy-aware_a_slices12_vnfs2_seed0_s12_v2_seed0.png
# [INFO] Saved route plot to ./results/2025-12-09_15-00-33/routes/routes_milp_sequential_slices12_vnfs2_seed0_s12_v2_seed0.png
# [INFO] Saved CPU utilization chart to ./results/2025-12-09_15-00-33/cpu_usage/cpu_utilization_s12_v2_seed0.png
#
# [INFO] === Running Load Test: 16 slices × 2 VNFs (total=32), seed=0 ===
#
# [INFO][A*] === Solving slice 1 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 1 accepted.
#
#
# [INFO][A*] === Solving slice 2 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 2 accepted.
#
#
# [INFO][A*] === Solving slice 3 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 3 accepted.
#
#
# [INFO][A*] === Solving slice 4 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 4 accepted.
#
#
# [INFO][A*] === Solving slice 5 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 5 accepted.
#
#
# [INFO][A*] === Solving slice 6 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 6 accepted.
#
#
# [INFO][A*] === Solving slice 7 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 7 accepted.
#
#
# [INFO][A*] === Solving slice 8 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 8 accepted.
#
#
# [INFO][A*] === Solving slice 9 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 9 accepted.
#
#
# [INFO][A*] === Solving slice 10 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 10 accepted.
#
#
# [INFO][A*] === Solving slice 11 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 11 accepted.
#
#
# [INFO][A*] === Solving slice 12 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 12 accepted.
#
#
# [INFO][A*] === Solving slice 13 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 6 expansions.
# [SUMMARY][A*] Slice 13 accepted.
#
#
# [INFO][A*] === Solving slice 14 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 5 expansions.
# [SUMMARY][A*] Slice 14 accepted.
#
#
# [INFO][A*] === Solving slice 15 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 4 expansions.
# [SUMMARY][A*] Slice 15 accepted.
#
#
# [INFO][A*] === Solving slice 16 (VNFs=2, VLs=1) ===
# [INFO][A*] Solution found after 8 expansions.
# [SUMMARY][A*] Slice 16 accepted.
#
#
# [INFO][ABO] === Solving slice 1 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 1 accepted. min_node_cpu=14, links_low_bw=0
#
# [INFO][ABO] === Solving slice 2 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 2 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][ABO] === Solving slice 3 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 3 accepted. min_node_cpu=10, links_low_bw=0
#
# [INFO][ABO] === Solving slice 4 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 4 accepted. min_node_cpu=8, links_low_bw=0
#
# [INFO][ABO] === Solving slice 5 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 5 accepted. min_node_cpu=6, links_low_bw=0
#
# [INFO][ABO] === Solving slice 6 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 6 accepted. min_node_cpu=4, links_low_bw=0
#
# [INFO][ABO] === Solving slice 7 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 7 accepted. min_node_cpu=2, links_low_bw=0
#
# [INFO][ABO] === Solving slice 8 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 10 states.
# [SUMMARY][ABO] Slice 8 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 9 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 9 states.
# [SUMMARY][ABO] Slice 9 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 10 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 9 states.
# [SUMMARY][ABO] Slice 10 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 11 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 9 states.
# [SUMMARY][ABO] Slice 11 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 12 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 9 states.
# [SUMMARY][ABO] Slice 12 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 13 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 9 states.
# [SUMMARY][ABO] Slice 13 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 14 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 9 states.
# [SUMMARY][ABO] Slice 14 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 15 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 9 states.
# [SUMMARY][ABO] Slice 15 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 16 (2 VNFs, 1 VLs) ===
# [INFO][ABO] Found feasible solution after 8 states.
# [SUMMARY][ABO] Slice 16 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][FABO] === Solving slice 1 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 1 accepted. min_node_cpu=14, links_low_bw=0
#
# [INFO][FABO] === Solving slice 2 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 2 accepted. min_node_cpu=13, links_low_bw=0
#
# [INFO][FABO] === Solving slice 3 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 3 accepted. min_node_cpu=13, links_low_bw=0
#
# [INFO][FABO] === Solving slice 4 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 4 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][FABO] === Solving slice 5 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 5 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][FABO] === Solving slice 6 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 6 accepted. min_node_cpu=12, links_low_bw=0
#
# [INFO][FABO] === Solving slice 7 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 7 accepted. min_node_cpu=10, links_low_bw=0
#
# [INFO][FABO] === Solving slice 8 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 8 accepted. min_node_cpu=10, links_low_bw=0
#
# [INFO][FABO] === Solving slice 9 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 9 accepted. min_node_cpu=10, links_low_bw=0
#
# [INFO][FABO] === Solving slice 10 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 10 accepted. min_node_cpu=8, links_low_bw=0
#
# [INFO][FABO] === Solving slice 11 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 11 accepted. min_node_cpu=8, links_low_bw=0
#
# [INFO][FABO] === Solving slice 12 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 12 accepted. min_node_cpu=8, links_low_bw=0
#
# [INFO][FABO] === Solving slice 13 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 13 accepted. min_node_cpu=6, links_low_bw=0
#
# [INFO][FABO] === Solving slice 14 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 14 accepted. min_node_cpu=6, links_low_bw=0
#
# [INFO][FABO] === Solving slice 15 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 15 accepted. min_node_cpu=6, links_low_bw=0
#
# [INFO][FABO] === Solving slice 16 (2 VNFs, 1 VLs) ===
# [INFO][FABO] Found feasible solution after 10 states.
# [SUMMARY][FABO] Slice 16 accepted. min_node_cpu=4, links_low_bw=0
#
# [INFO][BF] === Solving slice 1 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf0_0 on node 6 (use=2, remaining=62).
# [INFO][BF] Placed vnf0_1 on node 2 (use=3, remaining=13).
# [SUMMARY][BF] Slice 1 accepted. Remaining min_node_cpu=13, links_low_bw=0
#
# [INFO][BF] === Solving slice 2 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf1_0 on node 6 (use=2, remaining=60).
# [INFO][BF] Placed vnf1_1 on node 2 (use=3, remaining=10).
# [SUMMARY][BF] Slice 2 accepted. Remaining min_node_cpu=10, links_low_bw=0
#
# [INFO][BF] === Solving slice 3 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf2_0 on node 6 (use=2, remaining=58).
# [INFO][BF] Placed vnf2_1 on node 2 (use=3, remaining=7).
# [SUMMARY][BF] Slice 3 accepted. Remaining min_node_cpu=7, links_low_bw=0
#
# [INFO][BF] === Solving slice 4 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf3_0 on node 6 (use=2, remaining=56).
# [INFO][BF] Placed vnf3_1 on node 2 (use=3, remaining=4).
# [SUMMARY][BF] Slice 4 accepted. Remaining min_node_cpu=4, links_low_bw=0
#
# [INFO][BF] === Solving slice 5 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf4_0 on node 6 (use=2, remaining=54).
# [INFO][BF] Placed vnf4_1 on node 2 (use=3, remaining=1).
# [SUMMARY][BF] Slice 5 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 6 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf5_0 on node 6 (use=2, remaining=52).
# [INFO][BF] Placed vnf5_1 on node 5 (use=3, remaining=13).
# [SUMMARY][BF] Slice 6 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 7 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf6_0 on node 6 (use=2, remaining=50).
# [INFO][BF] Placed vnf6_1 on node 5 (use=3, remaining=10).
# [SUMMARY][BF] Slice 7 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 8 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf7_0 on node 6 (use=2, remaining=48).
# [INFO][BF] Placed vnf7_1 on node 5 (use=3, remaining=7).
# [SUMMARY][BF] Slice 8 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 9 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf8_0 on node 6 (use=2, remaining=46).
# [INFO][BF] Placed vnf8_1 on node 5 (use=3, remaining=4).
# [SUMMARY][BF] Slice 9 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 10 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf9_0 on node 6 (use=2, remaining=44).
# [INFO][BF] Placed vnf9_1 on node 5 (use=3, remaining=1).
# [SUMMARY][BF] Slice 10 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 11 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf10_0 on node 6 (use=2, remaining=42).
# [INFO][BF] Placed vnf10_1 on node 7 (use=3, remaining=13).
# [SUMMARY][BF] Slice 11 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 12 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf11_0 on node 6 (use=2, remaining=40).
# [INFO][BF] Placed vnf11_1 on node 7 (use=3, remaining=10).
# [SUMMARY][BF] Slice 12 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 13 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf12_0 on node 6 (use=2, remaining=38).
# [INFO][BF] Placed vnf12_1 on node 7 (use=3, remaining=7).
# [SUMMARY][BF] Slice 13 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 14 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf13_0 on node 6 (use=2, remaining=36).
# [INFO][BF] Placed vnf13_1 on node 7 (use=3, remaining=4).
# [SUMMARY][BF] Slice 14 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 15 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf14_0 on node 6 (use=2, remaining=34).
# [INFO][BF] Placed vnf14_1 on node 7 (use=3, remaining=1).
# [SUMMARY][BF] Slice 15 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][BF] === Solving slice 16 with 2 VNFs and 1 VLs ===
# [INFO][BF] Placed vnf15_0 on node 6 (use=2, remaining=32).
# [INFO][BF] Placed vnf15_1 on node 1 (use=3, remaining=61).
# [SUMMARY][BF] Slice 16 accepted. Remaining min_node_cpu=1, links_low_bw=0
#
# [INFO][FF] === Solving slice 1 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf0_0 on node 1 (use=2, remaining=62).
# [INFO][FF] Placed vnf0_1 on node 2 (use=3, remaining=13).
# [SUMMARY][FF] Slice 1 accepted. Remaining min_node_cpu=13, links_low_bw=0
#
# [INFO][FF] === Solving slice 2 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf1_0 on node 1 (use=2, remaining=60).
# [INFO][FF] Placed vnf1_1 on node 2 (use=3, remaining=10).
# [SUMMARY][FF] Slice 2 accepted. Remaining min_node_cpu=10, links_low_bw=0
#
# [INFO][FF] === Solving slice 3 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf2_0 on node 1 (use=2, remaining=58).
# [INFO][FF] Placed vnf2_1 on node 2 (use=3, remaining=7).
# [SUMMARY][FF] Slice 3 accepted. Remaining min_node_cpu=7, links_low_bw=0
#
# [INFO][FF] === Solving slice 4 with 2 VNFs and 1 VLs ===
# [INFO][FF] Placed vnf3_0 on node 1 (use=2, remaining=56).
# [INFO][FF] Placed vnf3_1 on node 2 (use=3, remaining=4).
# [SUMMARY][FF] Slice 4 accepted. Remaining min_node_cpu=4, links_low_bw=0
#
# [INFO][FF] === Solving slice 5 with 2 VNFs and 1 VLs ===
# ...
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=80, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=80, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=80, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=80, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=50, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=65, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=80, have=40
# [DEBUG][A*] Insufficient bandwidth on edge (1,3) need=80, have=40
# [INFO][A*] Solution found after 367 expansions.
# [SUMMARY][A*] Slice 8 accepted.
#
#
# [INFO][A*] === Solving slice 9 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 9 rejected.
#
#
# [INFO][A*] === Solving slice 10 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 10 rejected.
#
#
# [INFO][A*] === Solving slice 11 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 11 rejected.
#
#
# [INFO][A*] === Solving slice 12 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 12 rejected.
#
#
# [INFO][A*] === Solving slice 13 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 13 rejected.
#
#
# [INFO][A*] === Solving slice 14 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 14 rejected.
#
#
# [INFO][A*] === Solving slice 15 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 15 rejected.
#
#
# [INFO][A*] === Solving slice 16 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 16 rejected.
#
#
# [INFO][A*] === Solving slice 17 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 17 rejected.
#
#
# [INFO][A*] === Solving slice 18 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 18 rejected.
#
#
# [INFO][A*] === Solving slice 19 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 19 rejected.
#
#
# [INFO][A*] === Solving slice 20 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 20 rejected.
#
#
# [INFO][A*] === Solving slice 21 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 21 rejected.
#
#
# [INFO][A*] === Solving slice 22 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 22 rejected.
#
#
# [INFO][A*] === Solving slice 23 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 23 rejected.
#
#
# [INFO][A*] === Solving slice 24 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 24 rejected.
#
#
# [INFO][A*] === Solving slice 25 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 25 rejected.
#
#
# [INFO][A*] === Solving slice 26 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 26 rejected.
#
#
# [INFO][A*] === Solving slice 27 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 27 rejected.
#
#
# [INFO][A*] === Solving slice 28 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 28 rejected.
#
#
# [INFO][A*] === Solving slice 29 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 29 rejected.
#
#
# [INFO][A*] === Solving slice 30 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 30 rejected.
#
#
# [INFO][A*] === Solving slice 31 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 31 rejected.
#
#
# [INFO][A*] === Solving slice 32 (VNFs=6, VLs=5) ===
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=30, have=10
# [DEBUG][A*] Insufficient bandwidth on edge (3,1) need=40, have=10
# [WARN][A*] No feasible solution for slice after 13 expansions.
# [WARN][A*] Slice 32 rejected.
#
#
# [INFO][ABO] === Solving slice 1 (6 VNFs, 5 VLs) ===
# [INFO][ABO] Found feasible solution after 2259 states.
# [SUMMARY][ABO] Slice 1 accepted. min_node_cpu=6, links_low_bw=0
#
# [INFO][ABO] === Solving slice 2 (6 VNFs, 5 VLs) ===
# [INFO][ABO] Found feasible solution after 1728 states.
# [SUMMARY][ABO] Slice 2 accepted. min_node_cpu=2, links_low_bw=0
#
# [INFO][ABO] === Solving slice 3 (6 VNFs, 5 VLs) ===
# [INFO][ABO] Found feasible solution after 815 states.
# [SUMMARY][ABO] Slice 3 accepted. min_node_cpu=2, links_low_bw=0
#
# [INFO][ABO] === Solving slice 4 (6 VNFs, 5 VLs) ===
# [INFO][ABO] Found feasible solution after 657 states.
# [SUMMARY][ABO] Slice 4 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 5 (6 VNFs, 5 VLs) ===
# [INFO][ABO] Found feasible solution after 529 states.
# [SUMMARY][ABO] Slice 5 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 6 (6 VNFs, 5 VLs) ===
# [INFO][ABO] Found feasible solution after 393 states.
# [SUMMARY][ABO] Slice 6 accepted. min_node_cpu=0, links_low_bw=0
#
# [INFO][ABO] === Solving slice 7 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 7 rejected.
#
# [INFO][ABO] === Solving slice 8 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 8 rejected.
#
# [INFO][ABO] === Solving slice 9 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 9 rejected.
#
# [INFO][ABO] === Solving slice 10 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 10 rejected.
#
# [INFO][ABO] === Solving slice 11 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 11 rejected.
#
# [INFO][ABO] === Solving slice 12 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 12 rejected.
#
# [INFO][ABO] === Solving slice 13 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 13 rejected.
#
# [INFO][ABO] === Solving slice 14 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 14 rejected.
#
# [INFO][ABO] === Solving slice 15 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 15 rejected.
#
# [INFO][ABO] === Solving slice 16 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 16 rejected.
#
# [INFO][ABO] === Solving slice 17 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 17 rejected.
#
# [INFO][ABO] === Solving slice 18 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 18 rejected.
#
# [INFO][ABO] === Solving slice 19 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 19 rejected.
#
# [INFO][ABO] === Solving slice 20 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 20 rejected.
#
# [INFO][ABO] === Solving slice 21 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 21 rejected.
#
# [INFO][ABO] === Solving slice 22 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 22 rejected.
#
# [INFO][ABO] === Solving slice 23 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 23 rejected.
#
# [INFO][ABO] === Solving slice 24 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 24 rejected.
#
# [INFO][ABO] === Solving slice 25 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 25 rejected.
#
# [INFO][ABO] === Solving slice 26 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 26 rejected.
#
# [INFO][ABO] === Solving slice 27 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 27 rejected.
#
# [INFO][ABO] === Solving slice 28 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 28 rejected.
#
# [INFO][ABO] === Solving slice 29 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 29 rejected.
#
# [INFO][ABO] === Solving slice 30 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 30 rejected.
#
# [INFO][ABO] === Solving slice 31 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 31 rejected.
#
# [INFO][ABO] === Solving slice 32 (6 VNFs, 5 VLs) ===
# [WARN][ABO] No feasible solution for this slice.
# [SUMMARY][ABO] Slice 32 rejected.
#
# [INFO][FABO] === Solving slice 1 (6 VNFs, 5 VLs) ===
# [INFO][FABO] Found feasible solution after 2201 states.
# [SUMMARY][FABO] Slice 1 accepted. min_node_cpu=6, links_low_bw=0
#
# [INFO][FABO] === Solving slice 2 (6 VNFs, 5 VLs) ===

# %%
import pandas as pd

# Carregar o CSV
df_results = pd.read_csv("./results/2025-12-09_18-42-13/scalability_results.csv")

# Número de VNFs por slice que você quer analisar
vnf_len = 2   # ajuste para 2,3,4,5,6…

# Filtrar somente VNFs desejado
df_exp = df_results[df_results["num_vnfs_per_slice"] == vnf_len].copy()

# Criar acceptance_rate
df_exp["acceptance_rate"] = df_exp["accepted"] / df_exp["num_slices"]

# Filtrar apenas métodos desejados
METHODS_ALLOWED = ["A*", "ABO", "FABO"]
# Captura também MILP, pode ser MILP_Sequential, MILP_Gurobi, etc.
df_exp = df_exp[df_exp["method"].isin(METHODS_ALLOWED) | df_exp["method"].str.contains("MILP")]

print("[INFO] Linhas após filtrar métodos:", len(df_exp))

# Filtrar cenários com 100% aceitação
df_ok = df_exp[df_exp["acceptance_rate"] == 1.0].copy()

print("[INFO] Linhas após filtrar 100% aceitação:", len(df_ok))
display(df_ok.head())

# ==============================
# 1) Accepted slices vs num_slices (100% acceptance)
# ==============================

pivot_acc = df_ok.pivot_table(
    index="num_slices",
    columns="method",
    values="accepted",
    aggfunc="mean",
).sort_index()

print("\n=== Accepted slices vs num_slices (100% acceptance, VNFs={}) ===".format(vnf_len))
display(pivot_acc)

# ==============================
# 2) Total energy vs num_slices (100% acceptance)
# ==============================

pivot_energy = df_ok.pivot_table(
    index="num_slices",
    columns="method",
    values="total_energy",
    aggfunc="mean",
).sort_index()

print("\n=== Total energy vs num_slices (100% acceptance, VNFs={}) ===".format(vnf_len))
display(pivot_energy)

# ==============================
# PLOTS
# ==============================

# Accepted slices plot
try:
    ax = pivot_acc.plot(marker="o", figsize=(10, 5),
        title=f"Accepted slices vs num_slices (100% acceptance, VNFs={vnf_len})")
    ax.set_xlabel("num_slices")
    ax.set_ylabel("accepted")
except Exception as e:
    print("[WARN] Could not plot acceptance:", e)

# Energy plot
try:
    ax = pivot_energy.plot(marker="o", figsize=(10, 5),
        title=f"Energy vs num_slices (100% acceptance, VNFs={vnf_len})")
    ax.set_xlabel("num_slices")
    ax.set_ylabel("total_energy")
except Exception as e:
    print("[WARN] Could not plot energy:", e)
# Out:
# [INFO] Linhas após filtrar métodos: 100
# [INFO] Linhas após filtrar 100% aceitação: 70
#              timestamp  num_slices  num_vnfs_per_slice  total_vnfs  seed  \
# 0  2025-12-09 18:42:28           8                   2          16     1
# 1  2025-12-09 18:42:37           8                   2          16     1
# 2  2025-12-09 18:42:37           8                   2          16     1
# 3  2025-12-09 18:42:37           8                   2          16     1
# 7  2025-12-09 18:43:06          16                   2          32     1
#
#             method  accepted  total_energy  total_bandwidth  total_latency  \
# 0  MILP_Sequential         8      1.345000              NaN            NaN
# 1               A*         8      9.230000            240.0            8.0
# 2              ABO         8      4.615000            240.0           16.0
# 3             FABO         8     17.156875            240.0           16.0
# 7  MILP_Sequential        16      2.690000              NaN            NaN
#
#    runtime_sec  acceptance_rate
# 0     0.069197              1.0
# 1     0.078109              1.0
# 2     7.565059              1.0
# 3     7.626298              1.0
# 7     0.121804              1.0
# === Accepted slices vs num_slices (100% acceptance, VNFs=2) ===
# method        A*   ABO  FABO  MILP_Sequential
# num_slices
# 8            8.0   8.0   8.0              8.0
# 16          16.0  16.0  16.0             16.0
# 32          32.0  32.0  32.0             32.0
# 64           NaN   NaN  64.0             64.0
# === Total energy vs num_slices (100% acceptance, VNFs=2) ===
# method             A*       ABO       FABO  MILP_Sequential
# num_slices
# 8            9.230000   4.61500  17.156875          1.34500
# 16          13.349375  16.16375  21.253750          2.69000
# 32          22.883125  32.19750  34.083125          6.11375
# 64                NaN       NaN  52.842500         15.87750

# %%
import pandas as pd

# Carregar o CSV
df_results = pd.read_csv("./results/2025-12-08_08-33-59/scalability_results.csv")

# Número de VNFs por slice que você quer analisar
vnf_len = 3   # ajuste para 2,3,4,5,6…

# Filtrar somente VNFs desejado
df_exp = df_results[df_results["num_vnfs_per_slice"] == vnf_len].copy()

# Criar acceptance_rate
df_exp["acceptance_rate"] = df_exp["accepted"] / df_exp["num_slices"]

# Filtrar apenas métodos desejados
METHODS_ALLOWED = ["A*", "ABO", "FABO"]
# Captura também MILP, pode ser MILP_Sequential, MILP_Gurobi, etc.
df_exp = df_exp[df_exp["method"].isin(METHODS_ALLOWED) | df_exp["method"].str.contains("MILP")]

print("[INFO] Linhas após filtrar métodos:", len(df_exp))

# Filtrar cenários com 100% aceitação
df_ok = df_exp[df_exp["acceptance_rate"] == 1.0].copy()

print("[INFO] Linhas após filtrar 100% aceitação:", len(df_ok))
display(df_ok.head())

# ==============================
# 1) Accepted slices vs num_slices (100% acceptance)
# ==============================

pivot_acc = df_ok.pivot_table(
    index="num_slices",
    columns="method",
    values="accepted",
    aggfunc="mean",
).sort_index()

print("\n=== Accepted slices vs num_slices (100% acceptance, VNFs={}) ===".format(vnf_len))
display(pivot_acc)

# ==============================
# 2) Total energy vs num_slices (100% acceptance)
# ==============================

pivot_energy = df_ok.pivot_table(
    index="num_slices",
    columns="method",
    values="total_energy",
    aggfunc="mean",
).sort_index()

print("\n=== Total energy vs num_slices (100% acceptance, VNFs={}) ===".format(vnf_len))
display(pivot_energy)

# ==============================
# PLOTS
# ==============================

# Accepted slices plot
try:
    ax = pivot_acc.plot(marker="o", figsize=(10, 5),
        title=f"Accepted slices vs num_slices (100% acceptance, VNFs={vnf_len})")
    ax.set_xlabel("num_slices")
    ax.set_ylabel("accepted")
except Exception as e:
    print("[WARN] Could not plot acceptance:", e)

# Energy plot
try:
    ax = pivot_energy.plot(marker="o", figsize=(10, 5),
        title=f"Energy vs num_slices (100% acceptance, VNFs={vnf_len})")
    ax.set_xlabel("num_slices")
    ax.set_ylabel("total_energy")
except Exception as e:
    print("[WARN] Could not plot energy:", e)
# Out:
# [INFO] Linhas após filtrar métodos: 10
# [INFO] Linhas após filtrar 100% aceitação: 10
#               timestamp  num_slices  num_vnfs_per_slice  total_vnfs  seed  \
# 16  2025-12-08 08:35:54           8                   3          24     0
# 17  2025-12-08 08:36:04           8                   3          24     0
# 18  2025-12-08 08:36:04           8                   3          24     0
# 19  2025-12-08 08:36:04           8                   3          24     0
# 23  2025-12-08 08:36:04           8                   3          24     0
#
#              method  accepted  total_energy  total_bandwidth  total_latency  \
# 16  MILP_Sequential         8      3.248125              NaN            NaN
# 17               A*         8     20.107500            560.0           16.0
# 18              ABO         8     17.057500            560.0           24.0
# 19             FABO         8     21.987500            560.0           24.0
# 23  MILP_Sequential         8     12.248125             70.0           25.0
#
#     runtime_sec  acceptance_rate
# 16     0.082905              1.0
# 17     0.404435              1.0
# 18    27.512173              1.0
# 19    23.765748              1.0
# 23     0.082905              1.0
# === Accepted slices vs num_slices (100% acceptance, VNFs=3) ===
# method        A*   ABO  FABO  MILP_Sequential
# num_slices
# 8            8.0   8.0   8.0              8.0
# 16          16.0  16.0  16.0             16.0
# === Total energy vs num_slices (100% acceptance, VNFs=3) ===
# method             A*        ABO       FABO  MILP_Sequential
# num_slices
# 8           20.107500  17.057500  21.987500         7.748125
# 16          28.331875  37.049375  40.171875        12.703750

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Find latest results directory
results_base = "./results"
dirs = [d for d in os.listdir(results_base) if os.path.isdir(os.path.join(results_base, d))]
if not dirs:
    raise RuntimeError("No results found in ./results")

latest = sorted(dirs)[-1]
csv_path = os.path.join(results_base, latest, "scalability_results.csv")

df = pd.read_csv(csv_path)

# Prepare plot: total_energy vs accepted, grouped by method
methods = df["method"].unique()

plt.figure(figsize=(10,6))

for m in methods:
    sub = df[df["method"] == m]
    plt.plot(sub["accepted"], sub["total_energy"], marker="o", label=m)

plt.xlabel("Accepted slices")
plt.ylabel("Total energy")
plt.title("Energy vs Accepted Slices for All Methods")
plt.legend()
plt.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 14
#      11 latest = sorted(dirs)[-1]
#      12 csv_path = os.path.join(results_base, latest, "scalability_results.csv")
# ---> 14 df = pd.read_csv(csv_path)
#      16 # Prepare plot: total_energy vs accepted, grouped by method
#      17 methods = df["method"].unique()
#
# File ~/5g-slicing-energy-effiiciency/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/5g-slicing-energy-effiiciency/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/5g-slicing-energy-effiiciency/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/5g-slicing-energy-effiiciency/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/5g-slicing-energy-effiiciency/venv/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './results/2025-12-09_09-53-55/scalability_results.csv'
